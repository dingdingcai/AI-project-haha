# %%
import numpy as np
import os
import sys, time
sys.path.append('../')

import matplotlib.pyplot as plt
# %matplotlib inline

from model.loss import change_mask_loss, focal_loss_3
from model.metric import change_mask_all_accuracy, accuracy_3, count_accuracy
from keras.applications.xception import preprocess_input
from keras.callbacks import Callback, EarlyStopping
from model.DepthwiseConv2D import DepthwiseConv2D
from model.switchnorm import SwitchNormalization
from keras.utils import multi_gpu_model
from keras.optimizers import *
from keras.models import load_model  
from IPython.display import SVG
from keras.utils import plot_model
from keras.utils.vis_utils import model_to_dot

from dataload.data_generator_Aim_Amp_Bim__Bmp_count_pro import *
from model.core_model import model_v6 as my_model

gpus = 2
os.environ["CUDA_VISIBLE_DEVICES"] = "0, 1"
config = tf.ConfigProto() 
config.gpu_options.per_process_gpu_memory_fraction = 0.95
session = tf.Session(config=config)

# %%
base_project = os.path.abspath('../')
data_dir    = os.path.join(base_project, 'dataspace')
model_name = 'model_v6'
image_size = (512, 512)
mask_size  = (63, 63)

# %%
threshold = 0
heatmap_height = mask_size[0]
heatmap_width  = mask_size[1]

train_batch_size = 48
valid_batch_size = 48
test_batch_size  = 48

train_gen = MyImageDataGenerator(
    preprocessing_function=preprocess_input,
    width_shift_range=0.05,
    height_shift_range=0.05,
    rotation_range=6,
    channel_shift_range=15,
    zoom_range=(.9, 1.1),
    horizontal_flip=True
)

gen = MyImageDataGenerator(preprocessing_function=preprocess_input)

# train_generator = train_gen.myflow_from_directory(os.path.join(data_dir, 'train'),
#                                                   target_size       = image_size,
#                                                   x_threshold       = threshold,
#                                                   y_threshold       = threshold,
#                                                   dataset_mode      = 'test',
#                                                   return_path       = True,
#                                                   heatmap_height    = heatmap_height,
#                                                   heatmap_width     = heatmap_width,
#                                                   batch_size        = train_batch_size)

# valid_generator = gen.myflow_from_directory(os.path.join(data_dir, 'valid'), 
#                                            target_size       = image_size,
#                                            x_threshold       = threshold,
#                                            y_threshold       = threshold,
#                                            dataset_mode      = 'test',
#                                            return_path       = True,
#                                            heatmap_height    = heatmap_height,
#                                            heatmap_width     = heatmap_width,
#                                            batch_size        = valid_batch_size)

test_generator = gen.myflow_from_directory(os.path.join(data_dir, 'test'), 
                                           target_size       = image_size,
                                           x_threshold       = threshold,
                                           y_threshold       = threshold,
                                           dataset_mode      = 'test',
                                           return_path       = True,
                                           heatmap_height    = heatmap_height,
                                           heatmap_width     = heatmap_width,
                                           batch_size        = valid_batch_size)
# train_samples_epoch = train_generator.data_num
# print("samples_train = {}".format(train_samples_epoch))

# steps_train = len(train_generator)
# print("steps_train = {}".format(steps_train))

# valid_samples_epoch = valid_generator.data_num
# print("samples_valid = {}".format(valid_samples_epoch))

# steps_valid = len(valid_generator)
# print("steps_valid = {}".format(steps_valid))

test_samples_epoch = test_generator.data_num
print("samples_test = {}".format(test_samples_epoch))

steps_test = len(test_generator)
print("steps_test = {}".format(steps_test))

# 3 搭建模型
# Out:
# Found 15907 image pairs.
# samples_test = 15907
# steps_test = 332

# %%
# Found 257107 image pairs.
# Found 88145 image pairs.
# Found 15907 image pairs.
# samples_train = 257107
# steps_train = 5357
# samples_valid = 88145
# steps_valid = 1837
# samples_test = 15907
# steps_test = 332

# %%
model = my_model()
model.summary()
SVG(model_to_dot(model, show_shapes=True).create(prog='dot', format='svg'))
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_3 (InputLayer)            (None, 63, 63, 1)    0
# __________________________________________________________________________________________________
# input_5 (InputLayer)            (None, 512, 512, 3)  0
# __________________________________________________________________________________________________
# input_4 (InputLayer)            (None, 512, 512, 3)  0
# __________________________________________________________________________________________________
# mp_conv_1 (Conv2D)              (None, 63, 63, 16)   144         input_3[0][0]
# __________________________________________________________________________________________________
# vision_model (Model)            [(None, 63, 63, 288) 10674848    input_4[0][0]
#                                                                  input_5[0][0]
# __________________________________________________________________________________________________
# mp_conv_1_bn (SwitchNormalizati (None, 63, 63, 16)   54          mp_conv_1[0][0]
# __________________________________________________________________________________________________
# low_inner_sub_a_inner_decrease  (None, 63, 63, 64)   18432       vision_model[2][0]
# __________________________________________________________________________________________________
# low_inner_sub_b_inner_decrease  (None, 63, 63, 64)   18432       vision_model[1][0]
# __________________________________________________________________________________________________
# mp_conv_1_ac (Activation)       (None, 63, 63, 16)   0           mp_conv_1_bn[0][0]
# __________________________________________________________________________________________________
# low_inner_sub_a_decrease (Conv2 (None, 63, 63, 64)   18432       vision_model[2][0]
# __________________________________________________________________________________________________
# low_inner_sub_b_decrease (Conv2 (None, 63, 63, 64)   18432       vision_model[1][0]
# __________________________________________________________________________________________________
# low_inner_sub_a_inner_decrease_ (None, 63, 63, 64)   198         low_inner_sub_a_inner_decrease[0]
# __________________________________________________________________________________________________
# low_inner_sub_b_inner_decrease_ (None, 63, 63, 64)   198         low_inner_sub_b_inner_decrease[0]
# __________________________________________________________________________________________________
# mp_conv_2 (Conv2D)              (None, 63, 63, 64)   9216        mp_conv_1_ac[0][0]
# __________________________________________________________________________________________________
# low_inner_sub_a_decrease_bn (Sw (None, 63, 63, 64)   198         low_inner_sub_a_decrease[0][0]
# __________________________________________________________________________________________________
# low_inner_sub_b_decrease_bn (Sw (None, 63, 63, 64)   198         low_inner_sub_b_decrease[0][0]
# __________________________________________________________________________________________________
# low_inner_sub_a_inner_decrease_ (None, 63, 63, 64)   0           low_inner_sub_a_inner_decrease_bn
# __________________________________________________________________________________________________
# low_inner_sub_b_inner_decrease_ (None, 63, 63, 64)   0           low_inner_sub_b_inner_decrease_bn
# __________________________________________________________________________________________________
# mp_conv_2_bn (SwitchNormalizati (None, 63, 63, 64)   198         mp_conv_2[0][0]
# __________________________________________________________________________________________________
# low_inner_sub_a_decrease_ac (Ac (None, 63, 63, 64)   0           low_inner_sub_a_decrease_bn[0][0]
# __________________________________________________________________________________________________
# low_inner_sub_b_decrease_ac (Ac (None, 63, 63, 64)   0           low_inner_sub_b_decrease_bn[0][0]
# __________________________________________________________________________________________________
# low_inner_sub_sub (Subtract)    (None, 63, 63, 64)   0           low_inner_sub_a_inner_decrease_ac
#                                                                  low_inner_sub_b_inner_decrease_ac
# __________________________________________________________________________________________________
# mp_conv_2_ac (Activation)       (None, 63, 63, 64)   0           mp_conv_2_bn[0][0]
# __________________________________________________________________________________________________
# low_inner_sub_out (Concatenate) (None, 63, 63, 192)  0           low_inner_sub_a_decrease_ac[0][0]
#                                                                  low_inner_sub_b_decrease_ac[0][0]
#                                                                  low_inner_sub_sub[0][0]
# __________________________________________________________________________________________________
# x_low_concat (Concatenate)      (None, 63, 63, 256)  0           mp_conv_2_ac[0][0]
#                                                                  low_inner_sub_out[0][0]
# __________________________________________________________________________________________________
# x_low_block_conv_1 (Conv2D)     (None, 63, 63, 128)  294912      x_low_concat[0][0]
# __________________________________________________________________________________________________
# x_low_block_conv_1_bn (SwitchNo (None, 63, 63, 128)  390         x_low_block_conv_1[0][0]
# __________________________________________________________________________________________________
# x_low_block_conv_1_ac (Activati (None, 63, 63, 128)  0           x_low_block_conv_1_bn[0][0]
# __________________________________________________________________________________________________
# x_low_block_conv_2 (Conv2D)     (None, 63, 63, 128)  147456      x_low_block_conv_1_ac[0][0]
# __________________________________________________________________________________________________
# x_low_block_conv_2_bn (SwitchNo (None, 63, 63, 128)  390         x_low_block_conv_2[0][0]
# __________________________________________________________________________________________________
# middle_inner_sub_a_inner_decrea (None, 31, 31, 128)  98304       vision_model[2][1]
# __________________________________________________________________________________________________
# middle_inner_sub_b_inner_decrea (None, 31, 31, 128)  98304       vision_model[1][1]
# __________________________________________________________________________________________________
# x_low_block_conv_2_ac (Activati (None, 63, 63, 128)  0           x_low_block_conv_2_bn[0][0]
# __________________________________________________________________________________________________
# middle_inner_sub_a_decrease (Co (None, 31, 31, 128)  98304       vision_model[2][1]
# __________________________________________________________________________________________________
# middle_inner_sub_b_decrease (Co (None, 31, 31, 128)  98304       vision_model[1][1]
# __________________________________________________________________________________________________
# middle_inner_sub_a_inner_decrea (None, 31, 31, 128)  390         middle_inner_sub_a_inner_decrease
# __________________________________________________________________________________________________
# middle_inner_sub_b_inner_decrea (None, 31, 31, 128)  390         middle_inner_sub_b_inner_decrease
# __________________________________________________________________________________________________
# x_low_block_downsample (Depthwi (None, 31, 31, 128)  1152        x_low_block_conv_2_ac[0][0]
# __________________________________________________________________________________________________
# middle_inner_sub_a_decrease_bn  (None, 31, 31, 128)  390         middle_inner_sub_a_decrease[0][0]
# __________________________________________________________________________________________________
# middle_inner_sub_b_decrease_bn  (None, 31, 31, 128)  390         middle_inner_sub_b_decrease[0][0]
# __________________________________________________________________________________________________
# middle_inner_sub_a_inner_decrea (None, 31, 31, 128)  0           middle_inner_sub_a_inner_decrease
# __________________________________________________________________________________________________
# middle_inner_sub_b_inner_decrea (None, 31, 31, 128)  0           middle_inner_sub_b_inner_decrease
# __________________________________________________________________________________________________
# x_low_block_downsample_bn (Swit (None, 31, 31, 128)  390         x_low_block_downsample[0][0]
# __________________________________________________________________________________________________
# middle_inner_sub_a_decrease_ac  (None, 31, 31, 128)  0           middle_inner_sub_a_decrease_bn[0]
# __________________________________________________________________________________________________
# middle_inner_sub_b_decrease_ac  (None, 31, 31, 128)  0           middle_inner_sub_b_decrease_bn[0]
# __________________________________________________________________________________________________
# middle_inner_sub_sub (Subtract) (None, 31, 31, 128)  0           middle_inner_sub_a_inner_decrease
#                                                                  middle_inner_sub_b_inner_decrease
# __________________________________________________________________________________________________
# x_low_block_downsample_ac (Acti (None, 31, 31, 128)  0           x_low_block_downsample_bn[0][0]
# __________________________________________________________________________________________________
# middle_inner_sub_out (Concatena (None, 31, 31, 384)  0           middle_inner_sub_a_decrease_ac[0]
#                                                                  middle_inner_sub_b_decrease_ac[0]
#                                                                  middle_inner_sub_sub[0][0]
# __________________________________________________________________________________________________
# x_middle_concat (Concatenate)   (None, 31, 31, 512)  0           x_low_block_downsample_ac[0][0]
#                                                                  middle_inner_sub_out[0][0]
# __________________________________________________________________________________________________
# x_middle_block_conv_1 (Conv2D)  (None, 31, 31, 256)  1179648     x_middle_concat[0][0]
# __________________________________________________________________________________________________
# x_middle_block_conv_1_bn (Switc (None, 31, 31, 256)  774         x_middle_block_conv_1[0][0]
# __________________________________________________________________________________________________
# x_middle_block_conv_1_ac (Activ (None, 31, 31, 256)  0           x_middle_block_conv_1_bn[0][0]
# __________________________________________________________________________________________________
# x_middle_block_conv_2 (Conv2D)  (None, 31, 31, 256)  589824      x_middle_block_conv_1_ac[0][0]
# __________________________________________________________________________________________________
# x_middle_block_conv_2_bn (Switc (None, 31, 31, 256)  774         x_middle_block_conv_2[0][0]
# __________________________________________________________________________________________________
# high_inner_sub_a_inner_decrease (None, 15, 15, 128)  163840      vision_model[2][2]
# __________________________________________________________________________________________________
# high_inner_sub_b_inner_decrease (None, 15, 15, 128)  163840      vision_model[1][2]
# __________________________________________________________________________________________________
# x_middle_block_conv_2_ac (Activ (None, 31, 31, 256)  0           x_middle_block_conv_2_bn[0][0]
# __________________________________________________________________________________________________
# high_inner_sub_a_decrease (Conv (None, 15, 15, 128)  163840      vision_model[2][2]
# __________________________________________________________________________________________________
# high_inner_sub_b_decrease (Conv (None, 15, 15, 128)  163840      vision_model[1][2]
# __________________________________________________________________________________________________
# high_inner_sub_a_inner_decrease (None, 15, 15, 128)  390         high_inner_sub_a_inner_decrease[0
# __________________________________________________________________________________________________
# high_inner_sub_b_inner_decrease (None, 15, 15, 128)  390         high_inner_sub_b_inner_decrease[0
# __________________________________________________________________________________________________
# x_middle_block_downsample (Dept (None, 15, 15, 256)  2304        x_middle_block_conv_2_ac[0][0]
# __________________________________________________________________________________________________
# high_inner_sub_a_decrease_bn (S (None, 15, 15, 128)  390         high_inner_sub_a_decrease[0][0]
# __________________________________________________________________________________________________
# high_inner_sub_b_decrease_bn (S (None, 15, 15, 128)  390         high_inner_sub_b_decrease[0][0]
# __________________________________________________________________________________________________
# high_inner_sub_a_inner_decrease (None, 15, 15, 128)  0           high_inner_sub_a_inner_decrease_b
# __________________________________________________________________________________________________
# high_inner_sub_b_inner_decrease (None, 15, 15, 128)  0           high_inner_sub_b_inner_decrease_b
# __________________________________________________________________________________________________
# x_middle_block_downsample_bn (S (None, 15, 15, 256)  774         x_middle_block_downsample[0][0]
# __________________________________________________________________________________________________
# high_inner_sub_a_decrease_ac (A (None, 15, 15, 128)  0           high_inner_sub_a_decrease_bn[0][0
# __________________________________________________________________________________________________
# high_inner_sub_b_decrease_ac (A (None, 15, 15, 128)  0           high_inner_sub_b_decrease_bn[0][0
# __________________________________________________________________________________________________
# high_inner_sub_sub (Subtract)   (None, 15, 15, 128)  0           high_inner_sub_a_inner_decrease_a
#                                                                  high_inner_sub_b_inner_decrease_a
# __________________________________________________________________________________________________
# x_middle_block_downsample_ac (A (None, 15, 15, 256)  0           x_middle_block_downsample_bn[0][0
# __________________________________________________________________________________________________
# high_inner_sub_out (Concatenate (None, 15, 15, 384)  0           high_inner_sub_a_decrease_ac[0][0
#                                                                  high_inner_sub_b_decrease_ac[0][0
#                                                                  high_inner_sub_sub[0][0]
# __________________________________________________________________________________________________
# x_high_concat (Concatenate)     (None, 15, 15, 640)  0           x_middle_block_downsample_ac[0][0
#                                                                  high_inner_sub_out[0][0]
# __________________________________________________________________________________________________
# x_high_block_conv_1 (Conv2D)    (None, 15, 15, 256)  1474560     x_high_concat[0][0]
# __________________________________________________________________________________________________
# x_high_block_conv_1_bn (SwitchN (None, 15, 15, 256)  774         x_high_block_conv_1[0][0]
# __________________________________________________________________________________________________
# x_high_block_conv_1_ac (Activat (None, 15, 15, 256)  0           x_high_block_conv_1_bn[0][0]
# __________________________________________________________________________________________________
# x_high_block_conv_2 (Conv2D)    (None, 15, 15, 256)  589824      x_high_block_conv_1_ac[0][0]
# __________________________________________________________________________________________________
# x_high_block_conv_2_bn (SwitchN (None, 15, 15, 256)  774         x_high_block_conv_2[0][0]
# __________________________________________________________________________________________________
# x_high_block_conv_2_ac (Activat (None, 15, 15, 256)  0           x_high_block_conv_2_bn[0][0]
# __________________________________________________________________________________________________
# x_high_block_upsample (Conv2DTr (None, 31, 31, 256)  589824      x_high_block_conv_2_ac[0][0]
# __________________________________________________________________________________________________
# x_high_block_upsample_bn (Switc (None, 31, 31, 256)  774         x_high_block_upsample[0][0]
# __________________________________________________________________________________________________
# x_high_block_upsample_ac (Activ (None, 31, 31, 256)  0           x_high_block_upsample_bn[0][0]
# __________________________________________________________________________________________________
# x_middle_up_concat (Concatenate (None, 31, 31, 512)  0           x_high_block_upsample_ac[0][0]
#                                                                  x_middle_block_conv_2_ac[0][0]
# __________________________________________________________________________________________________
# x_middle_up_block_conv_1 (Conv2 (None, 31, 31, 256)  1179648     x_middle_up_concat[0][0]
# __________________________________________________________________________________________________
# x_middle_up_block_conv_1_bn (Sw (None, 31, 31, 256)  774         x_middle_up_block_conv_1[0][0]
# __________________________________________________________________________________________________
# x_middle_up_block_conv_1_ac (Ac (None, 31, 31, 256)  0           x_middle_up_block_conv_1_bn[0][0]
# __________________________________________________________________________________________________
# x_middle_up_block_conv_2 (Conv2 (None, 31, 31, 256)  589824      x_middle_up_block_conv_1_ac[0][0]
# __________________________________________________________________________________________________
# x_middle_up_block_conv_2_bn (Sw (None, 31, 31, 256)  774         x_middle_up_block_conv_2[0][0]
# __________________________________________________________________________________________________
# x_middle_up_block_conv_2_ac (Ac (None, 31, 31, 256)  0           x_middle_up_block_conv_2_bn[0][0]
# __________________________________________________________________________________________________
# x_middle_up_block_upsample (Con (None, 63, 63, 128)  294912      x_middle_up_block_conv_2_ac[0][0]
# __________________________________________________________________________________________________
# x_middle_up_block_upsample_bn ( (None, 63, 63, 128)  390         x_middle_up_block_upsample[0][0]
# __________________________________________________________________________________________________
# x_middle_up_block_upsample_ac ( (None, 63, 63, 128)  0           x_middle_up_block_upsample_bn[0][
# __________________________________________________________________________________________________
# x_low_up_concat (Concatenate)   (None, 63, 63, 256)  0           x_middle_up_block_upsample_ac[0][
#                                                                  x_low_block_conv_2_ac[0][0]
# __________________________________________________________________________________________________
# x_low_up_block_conv_1 (Conv2D)  (None, 63, 63, 128)  294912      x_low_up_concat[0][0]
# __________________________________________________________________________________________________
# x_low_up_block_conv_1_bn (Switc (None, 63, 63, 128)  390         x_low_up_block_conv_1[0][0]
# __________________________________________________________________________________________________
# x_low_up_block_conv_1_ac (Activ (None, 63, 63, 128)  0           x_low_up_block_conv_1_bn[0][0]
# __________________________________________________________________________________________________
# x_low_up_block_conv_2 (Conv2D)  (None, 63, 63, 128)  147456      x_low_up_block_conv_1_ac[0][0]
# __________________________________________________________________________________________________
# x_low_up_block_conv_2_bn (Switc (None, 63, 63, 128)  390         x_low_up_block_conv_2[0][0]
# __________________________________________________________________________________________________
# x_low_up_block_conv_2_ac (Activ (None, 63, 63, 128)  0           x_low_up_block_conv_2_bn[0][0]
# __________________________________________________________________________________________________
# pooling (GlobalAveragePooling2D (None, 128)          0           x_low_up_block_conv_2_ac[0][0]
# __________________________________________________________________________________________________
# heatmap (Conv2D)                (None, 63, 63, 1)    129         x_low_up_block_conv_2_ac[0][0]
# __________________________________________________________________________________________________
# count (Dense)                   (None, 1)            129         pooling[0][0]
# ==================================================================================================
# Total params: 19,195,722
# Trainable params: 19,165,994
# Non-trainable params: 29,728
# __________________________________________________________________________________________________

# %%
model_path = os.path.join(base_project,  'checkpoints/' + model_name)
model=load_model(os.path.join(model_path, 'model_v6_201901181131_2.8505_0.9772_model_9183.h5'))
multi_model = multi_gpu_model(model, gpus=gpus)
# Out:
# /home/ubuntu/.pyenv/versions/anaconda3-5.2.0/lib/python3.6/site-packages/keras/engine/saving.py:292: UserWarning: No training configuration found in save file: the model was *not* compiled. Compile it manually.
#   warnings.warn('No training configuration found in save file: '

# %%
import cv2
    
def NptoImg(x):
    return np.uint8(np.asarray((np.squeeze(x) + 1) * 127.5))

def ImgtoInput(x):
    return np.float64(x) / 127.5 - 1

def MptoImg(x):
    mp = np.squeeze(x)
    mp = mp - np.min(mp)
    mp = mp / (np.max(mp) + 1e-18)
    mp = np.uint8(mp * 255)
    return mp

def post_process_prob_argmax(y_pred, y_count, threshold=0.1, filter_size=3):
    h, w = y_pred.shape
    y_hat = np.zeros_like(y_pred)
    y_count = int(y_count.round())
    sz = int((filter_size - 1) / 2)
    range_size = [int(v) for v in np.linspace(-sz, sz, 2*sz+1)]
    y_pred[y_pred < threshold] = 0
    for i in range(h):
        for j in range(w):
            v_max = y_pred[i,j]
            ix_m = i
            iy_m = j
            flag = True
            for i_x in range_size:
                for i_y in range_size:
                    ix = i_x + i
                    iy = i_y + j
                    if i_x + i < 0:
                        ix = 0
                    if i_y + j < 0:
                        iy = 0
                    if i_x + i > h - 1:
                        ix = h - 1
                    if i_y + j > w - 1:
                        iy = w - 1
                    v_current = y_pred[ix, iy]
                    if v_max < v_current:
                        flag = False
            if flag:
                y_hat[ix_m, iy_m] = v_max
    
    y_hat_flatten = y_hat.flatten()
    y_sort_index = np.argsort(y_hat_flatten)         # ascending order
    
    N_largest_indice = y_sort_index[-y_count:]       # the N largest probabilities
    N_largest_prob = y_hat_flatten[N_largest_indice]
    y_hat_flatten[N_largest_indice] = 1
    y_hat_pred = y_hat_flatten.reshape((h, w))
    
    return y_hat_pred.round(), N_largest_prob


def display_image_heatmap(image_1, image_2, heatmp, names=None, cmap=None, norm=None, interpolation=None):
    image_1 = NptoImg(image_1)
    image_2 = NptoImg(image_2)
    heatmp = MptoImg(heatmp)

    plt.figure(figsize=(18, 18 * 3))
    plt.subplot(1, 3, 1)
    plt.axis('off')
    plt.imshow(image_1, cmap=cmap, norm=norm, interpolation=interpolation)
    if names is not None:
        plt.title(names[0])
    
    plt.subplot(1, 3, 2)
    plt.axis('off')
    plt.imshow(image_2, cmap=cmap, norm=norm, interpolation=interpolation)
    if names is not None:
        plt.title(names[1])
    
    plt.subplot(1, 3, 3)
    plt.axis('off')
    plt.imshow(heatmp, cmap=cmap, norm=norm, interpolation=interpolation)
    if names is not None:
        plt.title(names[2])
    
    plt.show()

def add_weight(img, in_x, weight=0.4, if_filter=False, black=False):
    cam = cv2.resize(in_x, (512, 512), interpolation=cv2.INTER_NEAREST)
    if if_filter:
        heatmap = np.tile(np.uint8(255*cam)[:, :, np.newaxis], (1, 1, 3))
    else:
        heatmap = cv2.applyColorMap(np.uint8(255*cam), cv2.COLORMAP_JET)
    out = cv2.addWeighted(img, 1.0, heatmap, weight, 0)
    if black:
        out[heatmap>225] = 0
    out = out[:, :, ::-1]
    return out

def display_image(imgs, names=None, sz=20):
    N = len(imgs)
    plt.figure(figsize=(sz, sz * N))
    for i in range(N):
        plt.subplot(1, N, i + 1)
        plt.imshow(imgs[i])
        if names[i]:
            plt.title(names[i])

# %%
eval_generator = test_generator
eval_steps = steps_test
eval_generator.reset()

# %%
x, y, file_path = eval_generator.next()

# %%
# idx = 29
idx = 1
black = True
# black = False
sz        = 18
x_img_A      = x[0][idx]
x_img_B      = x[1][idx]
x_map_A      = x[2][idx]
y_true_map_B = y[0][idx]
y_true_count = y[1][idx]
aux_info     = file_path[idx]
a_path       = aux_info[0]
b_path       = aux_info[1]

x_input_a    = np.expand_dims(x_img_A, 0)
x_input_b    = np.expand_dims(x_img_B, 0)
x_input_map  = np.expand_dims(x_map_A, 0)
y_max_prob_B, y_pred_count = model.predict([x_input_a, x_input_b, x_input_map])
y_true_map_B = y_true_map_B.squeeze()
y_max_prob_B = y_max_prob_B.squeeze()
y_pred_count = y_pred_count.squeeze()
x_map_A      = x_map_A.squeeze()

y_max_pred_B, y_probilities = post_process_prob_argmax(y_max_prob_B, y_pred_count, filter_size=5)

if y_pred_count.round() > 25:
    y_max_pred_B, y_probilities = post_process_prob_argmax(y_max_prob_B, y_pred_count, filter_size=3)
    
if y_probilities[0] < 0.1:
    y_max_pred_B, y_probilities = post_process_prob_argmax(y_max_prob_B, y_pred_count, filter_size=3)

y_true_diff_max   = y_true_map_B - y_max_pred_B
y_pred_diff_x     = x_map_A  - y_max_pred_B

img_A = cv2.imread(a_path) # BGR
img_A = cv2.resize(img_A, image_size)
img_B = cv2.imread(b_path) # BGR
img_B = cv2.resize(img_B, image_size)
true_mask_A = add_weight(img_A, x_map_A,      if_filter=True, weight=1, black=black)
true_mask_B = add_weight(img_B, y_true_map_B, if_filter=True, weight=1, black=black)
prob_mask_B = add_weight(img_B, y_max_prob_B, if_filter=True, weight=1, black=black)
pred_mask_B = add_weight(img_B, y_max_pred_B, if_filter=True, weight=1, black=black)

show_image_1 = [true_mask_A,        true_mask_B]
show_names_1 = ['A with true mask', 'B with true mask']
display_image(show_image_1, show_names_1, sz=sz)

show_image_2 = [ prob_mask_B,        pred_mask_B]
show_names_2 = ['Probabilities',    'B with pred mask']
display_image(show_image_2, show_names_2, sz=sz)

show_image_3 = [y_max_prob_B,       y_max_pred_B,       y_true_diff_max]
show_names_3 = ['B with prob mask', 'B pred via max_prob ', 'Difference']
display_image(show_image_3, show_names_3, sz=sz)

print(y_true_count, y_pred_count)
print(y_probilities)
# Out:
# [25.] 25.17352
# [0.40766573 0.4321017  0.45859244 0.47289458 0.4875523  0.4978743
#  0.49888882 0.49977562 0.58745426 0.6130926  0.6326159  0.64071906
#  0.6453556  0.65146554 0.6735241  0.69571006 0.7192913  0.739864
#  0.7400727  0.74376273 0.74676764 0.74687773 0.7701755  0.77889436
#  0.8092627 ]

# %%
eval_generator = valid_generator
eval_steps = steps_valid

# eval_generator = test_generator
# eval_steps = steps_test

eval_generator.reset()
counter = 0
counter_count = 0
for step in range(eval_steps):
    x, y, file_path = eval_generator.next()
    y_pred_map, y_pred_count = multi_model.predict_on_batch(x)
    for idx in range(len(y_pred_count)):
        counter += 1
        x_img_A      = x[0][idx]
        x_img_B      = x[1][idx]
        x_map_A      = x[2][idx]
        y_true_map_B = y[0][idx]
        y_true_count = y[1][idx]
        aux_info     = file_path[idx]

        x_input_a   = np.expand_dims(x_img_A, 0)
        x_input_b   = np.expand_dims(x_img_B, 0)
        x_input_map = np.expand_dims(x_map_A, 0)

        x_map_A      = x_map_A.squeeze()
        y_true_map_B = y_true_map_B.squeeze()
        y_pred_map_B = y_pred_map[idx, :, :, :].squeeze()
        y_pred_B_count = y_pred_count[idx, :].squeeze().round()

        if y_pred_B_count == y_true_count:
            counter_count += 1

    if (step + 1) % 10 == 0:
        print('{}/{}'.format(step+1, eval_steps))

print(counter_count / counter)
# Out:
# 10/1837
# 20/1837
# 30/1837
# 40/1837
# 50/1837
# 60/1837
# 70/1837
# 80/1837
# 90/1837
# 100/1837
# 110/1837
# 120/1837
# 130/1837
# 140/1837
# 150/1837
# 160/1837
# 170/1837
# 180/1837
# 190/1837
# 200/1837
# 210/1837
# 220/1837
# 230/1837
# 240/1837
# 250/1837
# 260/1837
# 270/1837
# 280/1837
# 290/1837
# 300/1837
# 310/1837
# 320/1837
# 330/1837
# 340/1837
# 350/1837
# 360/1837
# 370/1837
# 380/1837
# 390/1837
# 400/1837
# 410/1837
# 420/1837
# 430/1837
# 440/1837
# 450/1837
# 460/1837
# 470/1837
# 480/1837
# 490/1837
# 500/1837
# 510/1837
# 520/1837
# 530/1837
# 540/1837
# 550/1837
# 560/1837
# 570/1837
# 580/1837
# 590/1837
# 600/1837
# 610/1837
# 620/1837
# 630/1837
# 640/1837
# 650/1837
# 660/1837
# 670/1837
# 680/1837
# 690/1837
# 700/1837
# 710/1837
# 720/1837
# 730/1837
# 740/1837
# 750/1837
# 760/1837
# 770/1837
# 780/1837
# 790/1837
# 800/1837
# 810/1837
# 820/1837
# 830/1837
# 840/1837
# 850/1837
# 860/1837
# 870/1837
# 880/1837
# 890/1837
# 900/1837
# 910/1837
# 920/1837
# 930/1837
# 940/1837

# %%
# 0.9182749732822028
